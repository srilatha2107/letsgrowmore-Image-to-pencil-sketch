# %% [markdown]
# # Image to Pencil Sketch with Python

# %%
import cv2
from PIL import Image
from IPython.display import display

# %%
image = cv2.imread('Bipin Rawat.jpg')
display(Image.fromarray(image))
# Out:
# <PIL.Image.Image image mode=RGB size=278x334 at 0x2213CD39B80>

# %%
image = cv2.resize(image, (500, 500))
display(Image.fromarray(image))
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x2213DEDABE0>

# %%
img_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
display(Image.fromarray(img_rgb))
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x2212E61C100>

# %%
img_grey = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(img_grey))
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x2213DEDAE80>

# %%
img_inv = cv2.bitwise_not(img_grey)
display(Image.fromarray(img_inv))
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x2213DEDAC40>

# %%
img_smooth = cv2.GaussianBlur(img_inv, (5, 5), 0, 0)
display(Image.fromarray(img_smooth))
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x2213CD39BE0>

# %%
img_smooth_inv =  255- img_smooth
img_final = cv2.divide(img_grey, img_smooth_inv, scale=250.0)
display(Image.fromarray(img_final))
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x2213DEDAC70>

# %%
display(Image.fromarray(image))
display(Image.fromarray(img_final))
print('A TRIBUTE TO A WARRIOR -BIPIN RAWAT')
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x2213CBFB400>
# <PIL.Image.Image image mode=L size=500x500 at 0x2213DEDAA60>
# A TRIBUTE TO A WARRIOR -BIPIN RAWAT
